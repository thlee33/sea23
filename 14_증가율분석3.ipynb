# %% [markdown]
# ## 특정 영역(독도 반경 100km)의 증감률 분석
# 공간 : 주어진 좌표에서 일정 반경
# 시간 : 기준 시점 이전/이후
# 대상 : 수치형 속성 데이터 (격자별 수온 또는 생물종의 수 등)

# %% [markdown]
# ### 필요한 패키지(모듈/라이브러리) 준비

# %%
import numpy as np   #배열 등의 수치 데이터 처리용 패키지 
import xarray as xr  #netcdf와 같은 다차원 배열 데이터 처리용 패키지

# %%
import pandas as pd  #2차원 표 형태의 데이터프레임 처리용 패키지
import geopandas as gpd  #pandas를 기반으로 벡터 지오메트리(점/선/면)를 포함한 GeoDataFrame을 처리하는 패키지
from shapely.geometry import Point, Polygon #점, 선, 면 Geometry 처리용 패키지 
import plotly.express as px #차트 시각화 패키지 
pd.set_option('float_format', '{:f}'.format)  # 숫자가 지수 형태로 표시되지 않도록

# %% [markdown]
# ### 데이터 로딩
# EU Copernicus에서 제공하는 월별 해양 관측 데이터를 활용
# netcdf라는 시공간 다차원 데이터에 수온, 염분 등의 정보가 담겨있음
# https://resources.marine.copernicus.eu/?option=com_csw&view=details&product_id=MULTIOBS_GLO_PHY_TSUV_3D_MYNRT_015_012

# %%
ds2006 = xr.open_dataset('../data/netcdf/2020/dataset-armor-3d-rep-monthly_20200615T1200Z_P20211122T1135Z.nc')  
ds2006
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 1, depth: 50, latitude: 689, longitude: 1440)
# Coordinates:
#   * time       (time) datetime64[ns] 2020-06-15T12:00:00
#   * depth      (depth) int16 0 5 10 15 20 25 ... 3000 3500 4000 4500 5000 5500
#   * latitude   (latitude) float32 -82.12 -81.88 -81.62 ... 89.38 89.62 89.88
#   * longitude  (longitude) float32 0.125 0.375 0.625 0.875 ... 359.4 359.6 359.9
# Data variables:
#     so         (time, depth, latitude, longitude) float32 ...
#     to         (time, depth, latitude, longitude) float32 ...
#     ugo        (time, depth, latitude, longitude) float32 ...
#     vgo        (time, depth, latitude, longitude) float32 ...
#     zo         (time, depth, latitude, longitude) float32 ...
#     mlotst     (time, latitude, longitude) float32 ...
# Attributes:
#     description:  ARMOR3D REP CMEMS December 2020 Release
#     title:        ARMOR3D REP - TSHUVMld Global Ocean Observation-based Produ...
#     Conventions:  CF-1.0
#     institution:  CLS
#     domain_name:  GLO
#     history:      2020-06-15 00:00:00 ARMOR3D REP - TSHUV Global Ocean Observ...

# %%
# 나머지 연월별 데이터들도 로딩 
ds2007 = xr.open_dataset('../data/netcdf/2020/dataset-armor-3d-rep-monthly_20200715T1200Z_P20211122T1136Z.nc')  
ds2008 = xr.open_dataset('../data/netcdf/2020/dataset-armor-3d-rep-monthly_20200815T1200Z_P20211122T1137Z.nc')  
ds2106 = xr.open_dataset('../data/netcdf/2021/dataset-armor-3d-rep-monthly_20210615T1200Z_P20221118T1124Z.nc')  
ds2107 = xr.open_dataset('../data/netcdf/2021/dataset-armor-3d-rep-monthly_20210715T1200Z_P20221118T1126Z.nc')  
ds2108 = xr.open_dataset('../data/netcdf/2021/dataset-armor-3d-rep-monthly_20210815T1200Z_P20221118T1129Z.nc')

# %%
# 한반도 범위의 데이터들을 추출 - # 원하는 경도와 위도 범위 설정
lon_min, lon_max = 123, 133  # 경도 범위
lat_min, lat_max = 32, 43  # 위도 범위

# 해당 범위의 데이터 추출
ds2006 = ds2006.sel(longitude=slice(lon_min, lon_max), latitude=slice(lat_min, lat_max))
ds2007 = ds2007.sel(longitude=slice(lon_min, lon_max), latitude=slice(lat_min, lat_max))
ds2008 = ds2008.sel(longitude=slice(lon_min, lon_max), latitude=slice(lat_min, lat_max))
ds2106 = ds2106.sel(longitude=slice(lon_min, lon_max), latitude=slice(lat_min, lat_max))
ds2107 = ds2107.sel(longitude=slice(lon_min, lon_max), latitude=slice(lat_min, lat_max))
ds2108 = ds2108.sel(longitude=slice(lon_min, lon_max), latitude=slice(lat_min, lat_max))

# %%
# 데이터를 판다스 데이터프레임으로 변환 
df2006 = ds2006.to_dataframe().reset_index()
df2007 = ds2007.to_dataframe().reset_index()
df2008 = ds2008.to_dataframe().reset_index()

df2106 = ds2106.to_dataframe().reset_index()
df2107 = ds2107.to_dataframe().reset_index()
df2108 = ds2108.to_dataframe().reset_index()

# %%
# 데이터프레임의 기초 정보 확인
df2006.info()
df2006.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88000 entries, 0 to 87999
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   time       88000 non-null  datetime64[ns]
#  1   depth      88000 non-null  int16
#  2   latitude   88000 non-null  float32
#  3   longitude  88000 non-null  float32
#  4   so         31102 non-null  float32
#  5   to         31102 non-null  float32
#  6   ugo        24891 non-null  float32
#  7   vgo        25063 non-null  float32
#  8   zo         27874 non-null  float32
#  9   mlotst     61400 non-null  float32
# dtypes: datetime64[ns](1), float32(8), int16(1)
# memory usage: 3.5 MB
#                  time  depth  latitude  longitude         so         to  \
# 0 2020-06-15 12:00:00      0    32.125    123.125  31.301001  21.125000
# 1 2020-06-15 12:00:00      0    32.125    123.375  31.400002  20.431000
# 2 2020-06-15 12:00:00      0    32.125    123.625  31.518002  19.997000
# 3 2020-06-15 12:00:00      0    32.125    123.875  31.604000  19.955000
# 4 2020-06-15 12:00:00      0    32.125    124.125  31.707001  19.594999
#
#      ugo    vgo     zo     mlotst
# 0  0.054  0.185  0.769  11.099854
# 1  0.019  0.049  0.793  11.000000
# 2  0.013 -0.073  0.787  12.800049
# 3  0.015 -0.125  0.765  10.800049
# 4  0.031 -0.100  0.741  10.699951

# %%
# 2020년 6~8월 3개 데이터를 병합
df20_a = pd.concat([df2006, df2007, df2008], ignore_index=True)
df20_a.info()
df20_a.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264000 entries, 0 to 263999
# Data columns (total 10 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   time       264000 non-null  datetime64[ns]
#  1   depth      264000 non-null  int16
#  2   latitude   264000 non-null  float32
#  3   longitude  264000 non-null  float32
#  4   so         93306 non-null   float32
#  5   to         93306 non-null   float32
#  6   ugo        74673 non-null   float32
#  7   vgo        75189 non-null   float32
#  8   zo         83622 non-null   float32
#  9   mlotst     184200 non-null  float32
# dtypes: datetime64[ns](1), float32(8), int16(1)
# memory usage: 10.6 MB
#                  time  depth  latitude  longitude         so         to  \
# 0 2020-06-15 12:00:00      0    32.125    123.125  31.301001  21.125000
# 1 2020-06-15 12:00:00      0    32.125    123.375  31.400002  20.431000
# 2 2020-06-15 12:00:00      0    32.125    123.625  31.518002  19.997000
# 3 2020-06-15 12:00:00      0    32.125    123.875  31.604000  19.955000
# 4 2020-06-15 12:00:00      0    32.125    124.125  31.707001  19.594999
#
#      ugo    vgo     zo     mlotst
# 0  0.054  0.185  0.769  11.099854
# 1  0.019  0.049  0.793  11.000000
# 2  0.013 -0.073  0.787  12.800049
# 3  0.015 -0.125  0.765  10.800049
# 4  0.031 -0.100  0.741  10.699951

# %%
# 2021년 6~8월 3개 데이터를 병합
df21_a = pd.concat([df2106, df2107, df2108], ignore_index=True)

# %%
# 표층(depth = 0) 데이터만 추출
df20_b = df20_a[ df20_a['depth'] == 0   ]
df21_b = df21_a[ df21_a['depth'] == 0   ]

# %%
# 20년 데이터의 경도-위도별 평균 수온을 산출
df20_c = df20_b.groupby(['latitude', 'longitude'])['to'].mean().reset_index()
df20_c.info()
df20_c.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1760 entries, 0 to 1759
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   latitude   1760 non-null   float32
#  1   longitude  1760 non-null   float32
#  2   to         1228 non-null   float32
# dtypes: float32(3)
# memory usage: 20.8 KB
#    latitude  longitude         to
# 0    32.125    123.125  24.171333
# 1    32.125    123.375  23.760332
# 2    32.125    123.625  23.768667
# 3    32.125    123.875  23.738001
# 4    32.125    124.125  23.573334

# %%
# 21년 데이터의 경도-위도별 평균 수온을 산출
df21_c = df21_b.groupby(['latitude', 'longitude'])['to'].mean().reset_index()
df21_c.info()
df21_c.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1760 entries, 0 to 1759
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   latitude   1760 non-null   float32
#  1   longitude  1760 non-null   float32
#  2   to         1228 non-null   float32
# dtypes: float32(3)
# memory usage: 20.8 KB
#    latitude  longitude         to
# 0    32.125    123.125  25.633667
# 1    32.125    123.375  25.672998
# 2    32.125    123.625  25.632334
# 3    32.125    123.875  25.236000
# 4    32.125    124.125  25.035334

# %%
# 0.25도 간격의 폴리곤 생성 함수
def create_polygon(lat, lon):
    return Polygon([(lon, lat),
                    (lon + 0.25, lat),
                    (lon + 0.25, lat + 0.25),
                    (lon, lat + 0.25)])

# %%
# 각 좌표에 대한 폴리곤 생성
geometry20 = df20_c.apply(lambda row: create_polygon(row['latitude'], row['longitude']), axis=1)
# DataFrame을 GeoDataFrame으로 변환
gdf20 = gpd.GeoDataFrame(df20_c, geometry=geometry20, crs='4326')

# %%
# GeoDataFrame 기초정보 확인 
gdf20.info()
gdf20.head()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1760 entries, 0 to 1759
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   latitude   1760 non-null   float32
#  1   longitude  1760 non-null   float32
#  2   to         1228 non-null   float32
#  3   geometry   1760 non-null   geometry
# dtypes: float32(3), geometry(1)
# memory usage: 34.5 KB
#    latitude  longitude         to  \
# 0    32.125    123.125  24.171333
# 1    32.125    123.375  23.760332
# 2    32.125    123.625  23.768667
# 3    32.125    123.875  23.738001
# 4    32.125    124.125  23.573334
#
#                                             geometry
# 0  POLYGON ((123.12500 32.12500, 123.37500 32.125...
# 1  POLYGON ((123.37500 32.12500, 123.62500 32.125...
# 2  POLYGON ((123.62500 32.12500, 123.87500 32.125...
# 3  POLYGON ((123.87500 32.12500, 124.12500 32.125...
# 4  POLYGON ((124.12500 32.12500, 124.37500 32.125...

# %%
# 2021년 데이터도 공간데이터화 
# 각 좌표에 대한 폴리곤 생성
geometry21 = df21_c.apply(lambda row: create_polygon(row['latitude'], row['longitude']), axis=1)
# DataFrame을 GeoDataFrame으로 변환
gdf21 = gpd.GeoDataFrame(df21_c, geometry=geometry21, crs='4326')

# %%
gdf20.explore('to')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_80079a79ce09c44b5e04fd8f918b3f1e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_80079a79ce09c44b5e04fd8f918b3f1e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_80079a79ce09c44b5e04fd8f918b3f1e = L.map(
#                 &quot;map_80079a79ce09c44b5e04fd8f918b3f1e&quot;,
#                 {
#                     center: [37.625, 128.125],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_80079a79ce09c44b5e04fd8f918b3f1e);
#
#
#
#
#
#             var tile_layer_d9a4a7909e0013ff2e02e44ac9c1fb89 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_80079a79ce09c44b5e04fd8f918b3f1e);
#
#
#             map_80079a79ce09c44b5e04fd8f918b3f1e.fitBounds(
#                 [[32.125, 123.125], [43.125, 133.125]],
#                 {}
#             );
#
#
#         function geo_json_d0ae3af1569528dafbb873aeebaa1121_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;86&quot;: case &quot;89&quot;: case &quot;90&quot;: case &quot;130&quot;: case &quot;131&quot;: case &quot;225&quot;: case &quot;226&quot;: case &quot;227&quot;: case &quot;345&quot;: case &quot;598&quot;:
#                     return {&quot;color&quot;: &quot;#75d054&quot;, &quot;fillColor&quot;: &quot;#75d054&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;3&quot;: case &quot;5&quot;: case &quot;40&quot;: case &quot;202&quot;: case &quot;247&quot;: case &quot;425&quot;: case &quot;469&quot;: case &quot;553&quot;:
#                     return {&quot;color&quot;: &quot;#60ca60&quot;, &quot;fillColor&quot;: &quot;#60ca60&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;124&quot;: case &quot;164&quot;: case &quot;169&quot;: case &quot;203&quot;: case &quot;204&quot;: case &quot;211&quot;: case &quot;244&quot;: case &quot;246&quot;: case &quot;385&quot;: case &quot;596&quot;: case &quot;638&quot;:
#                     return {&quot;color&quot;: &quot;#63cb5f&quot;, &quot;fillColor&quot;: &quot;#63cb5f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;80&quot;: case &quot;121&quot;: case &quot;242&quot;: case &quot;426&quot;: case &quot;467&quot;: case &quot;679&quot;:
#                     return {&quot;color&quot;: &quot;#58c765&quot;, &quot;fillColor&quot;: &quot;#58c765&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;: case &quot;46&quot;: case &quot;85&quot;: case &quot;87&quot;: case &quot;88&quot;: case &quot;129&quot;: case &quot;173&quot;: case &quot;267&quot;: case &quot;270&quot;: case &quot;429&quot;: case &quot;639&quot;:
#                     return {&quot;color&quot;: &quot;#73d056&quot;, &quot;fillColor&quot;: &quot;#73d056&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;: case &quot;8&quot;: case &quot;12&quot;: case &quot;47&quot;: case &quot;49&quot;: case &quot;132&quot;: case &quot;314&quot;: case &quot;513&quot;: case &quot;515&quot;: case &quot;519&quot;:
#                     return {&quot;color&quot;: &quot;#7cd250&quot;, &quot;fillColor&quot;: &quot;#7cd250&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;9&quot;: case &quot;11&quot;: case &quot;48&quot;: case &quot;52&quot;: case &quot;92&quot;: case &quot;174&quot;: case &quot;391&quot;: case &quot;472&quot;: case &quot;557&quot;:
#                     return {&quot;color&quot;: &quot;#81d34d&quot;, &quot;fillColor&quot;: &quot;#81d34d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;: case &quot;107&quot;: case &quot;216&quot;: case &quot;266&quot;: case &quot;471&quot;: case &quot;599&quot;:
#                     return {&quot;color&quot;: &quot;#84d44b&quot;, &quot;fillColor&quot;: &quot;#84d44b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};

# %%
gdf21.explore('to')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e4934c7690150e4747def627d6e374ae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e4934c7690150e4747def627d6e374ae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e4934c7690150e4747def627d6e374ae = L.map(
#                 &quot;map_e4934c7690150e4747def627d6e374ae&quot;,
#                 {
#                     center: [37.625, 128.125],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e4934c7690150e4747def627d6e374ae);
#
#
#
#
#
#             var tile_layer_e9799b69b8da08fac284e0487c99c6d6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e4934c7690150e4747def627d6e374ae);
#
#
#             map_e4934c7690150e4747def627d6e374ae.fitBounds(
#                 [[32.125, 123.125], [43.125, 133.125]],
#                 {}
#             );
#
#
#         function geo_json_3554493b3ed98a20cf8e3ace3426d738_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;2&quot;: case &quot;12&quot;: case &quot;52&quot;: case &quot;303&quot;:
#                     return {&quot;color&quot;: &quot;#a2da37&quot;, &quot;fillColor&quot;: &quot;#a2da37&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;92&quot;: case &quot;104&quot;: case &quot;133&quot;: case &quot;146&quot;: case &quot;175&quot;: case &quot;304&quot;:
#                     return {&quot;color&quot;: &quot;#a5db36&quot;, &quot;fillColor&quot;: &quot;#a5db36&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;9&quot;: case &quot;47&quot;: case &quot;81&quot;: case &quot;83&quot;: case &quot;84&quot;: case &quot;87&quot;: case &quot;122&quot;: case &quot;127&quot;: case &quot;166&quot;: case &quot;168&quot;: case &quot;204&quot;: case &quot;205&quot;: case &quot;244&quot;: case &quot;245&quot;: case &quot;250&quot;: case &quot;285&quot;: case &quot;314&quot;: case &quot;343&quot;: case &quot;384&quot;:
#                     return {&quot;color&quot;: &quot;#8ed645&quot;, &quot;fillColor&quot;: &quot;#8ed645&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;5&quot;: case &quot;215&quot;: case &quot;340&quot;: case &quot;367&quot;: case &quot;388&quot;: case &quot;419&quot;: case &quot;424&quot;: case &quot;428&quot;: case &quot;429&quot;: case &quot;470&quot;: case &quot;471&quot;: case &quot;475&quot;:
#                     return {&quot;color&quot;: &quot;#84d44b&quot;, &quot;fillColor&quot;: &quot;#84d44b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;: case &quot;8&quot;: case &quot;44&quot;: case &quot;45&quot;: case &quot;46&quot;: case &quot;109&quot;: case &quot;121&quot;: case &quot;144&quot;: case &quot;164&quot;: case &quot;167&quot;: case &quot;173&quot;: case &quot;246&quot;: case &quot;269&quot;: case &quot;283&quot;: case &quot;284&quot;: case &quot;286&quot;: case &quot;326&quot;: case &quot;327&quot;: case &quot;342&quot;: case &quot;346&quot;: case &quot;366&quot;: case &quot;387&quot;:
#                     return {&quot;color&quot;: &quot;#89d548&quot;, &quot;fillColor&quot;: &quot;#89d548&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;: case &quot;43&quot;: case &quot;85&quot;: case &quot;120&quot;: case &quot;123&quot;: case &quot;128&quot;: case &quot;165&quot;: case &quot;203&quot;: case &quot;243&quot;: case &quot;248&quot;: case &quot;251&quot;: case &quot;252&quot;: case &quot;299&quot;: case &quot;345&quot;: case &quot;459&quot;:
#                     return {&quot;color&quot;: &quot;#8bd646&quot;, &quot;fillColor&quot;: &quot;#8bd646&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;: case &quot;29&quot;: case &quot;41&quot;: case &quot;89&quot;: case &quot;90&quot;: case &quot;145&quot;: case &quot;169&quot;: case &quot;174&quot;: case &quot;211&quot;: case &quot;3

# %% [markdown]
# #### 공간 영역 설정

# %% [markdown]
# https://www.openstreetmap.org/ 에 접속해서 '독도'를 검색하고, 울릉군 독도리에 해당하는 독도를 클릭하면 해당 위치로 지도가 표시됨
# 지도의 독도 상에서 컨텍스트 메뉴의 "여기를 가운데로 지정"를 선택하면, 독도에 대한 좌표가 URL에 보임
# https://www.openstreetmap.org/relation/6646538#map=16/37.2422/131.8669

# %% [markdown]
# 또는 epsg.io.map에 접속해도 쉽게 좌표를 확인할 수 있음
# https://epsg.io/map#srs=4326&x=131.866279&y=37.241672&z=15&layer=streets
# 131.866279 37.241672

# %%
# 특정 위도, 경도 및 버퍼 거리를 설정합니다.
longitude = 131.866279
latitude = 37.241672
buffer_distance = 100000   #100킬로미터  

# 경위도 Point GeoDataFrame을 생성합니다.
geom_latlon = Point(longitude, latitude)
gdf_pt4326 = gpd.GeoDataFrame(geometry=[geom_latlon], crs='epsg:4326' ) 

# Point GeoDataFrame을 평면직각좌표계(3857)로 변환
gdf_pt3857 = gdf_pt4326.to_crs(epsg=3857) 

# gdf_pt3857에 대한 버퍼 공간데이터를 생성 
geom_buf = gdf_pt3857.geometry.buffer(buffer_distance)

# 버퍼 폴리곤을 GeoDataFrame으로 변환합니다.
gdf_buf3857 = gpd.GeoDataFrame(geometry=geom_buf ) 

# 버퍼 폴리곤을 4326으로 변환 (생물종과 공간조인을 위해)
gdf_buf4326 = gdf_buf3857.to_crs(epsg=4326)

# %%
gdf_buf3857.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_25955a565d43c4916760584641b09371 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_25955a565d43c4916760584641b09371&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_25955a565d43c4916760584641b09371 = L.map(
#                 &quot;map_25955a565d43c4916760584641b09371&quot;,
#                 {
#                     center: [37.2382794558689, 131.86627899999996],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_25955a565d43c4916760584641b09371);
#
#
#
#
#
#             var tile_layer_a549eeda3b95e75f2ef5ff755b1f21aa = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_25955a565d43c4916760584641b09371);
#
#
#             map_25955a565d43c4916760584641b09371.fitBounds(
#                 [[36.52314750323181, 130.96796371588044], [37.953411408505985, 132.76459428411948]],
#                 {}
#             );
#
#
#         function geo_json_72d6251e1712551852210587d6b2e121_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_72d6251e1712551852210587d6b2e121_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_72d6251e1712551852210587d6b2e121_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_72d6251e1712551852210587d6b2e121_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_72d6251e1712551852210587d6b2e121_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_72d6251e1712551852210587d6b2e121.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_72d6251e1712551852210587d6b2e121_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_72d6251e1712551852210587d6b2e121 = L.geoJson(null, {
#                 onEachFeature: geo_json_72d6251e1712551852210587d6b2e121_onEachFeature,
#
#                 style: geo_json_72d6251e1712551852210587d6b2e121_styler,
#                 pointToLayer: geo_json_72d6251e1712551852210587d6b2e121_pointToLayer
#         });
#
#         function geo_json_72d6251e1712551852210587d6b2e121_add (data) {
#             geo_json_72d6251e1712551852210587d6b2e121
#                 .addData(data)
#                 .addTo(map_25955a565d43c4916760584641b09371);
#         }
#             geo_json_72d6251e1712551852210587d6b2e121_add({&quot;bbox&quot;: [130.96796371588044, 36.52314750323181, 132.76459428411948, 37.953411408505985], &quot;features&quot;: [{&quot;bbox&quot;: [130.96796371588044, 36.52314750323181, 132.76459428411948, 37.953411408505985], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[132.76459428411948, 37.241672], [132.7602686504919, 37.171543454848646], [132.74733340782566, 37.102026077858525], [132.7259131295787, 37.03379217977552], [132.69621410474008, 36.967503438351635], [132.6585223511541, 36.90380434956666], [132.61320086101227, 36.84331578516229], [132.5606861050399, 36.78662872770373], [132.50148382904442, 36.73429825454622], [132.43

# %%
# # 연도 구분 컬럼 생성
# gdf20['year'] = 2020
# 위도-경도를 이용한 고유ID 부여
gdf20['lat_lon'] = gdf20['latitude'].astype(str) + '_' + gdf20['longitude'].astype(str)
# 독도 반경 영역에 해당하는 데이터만 추출 
gdf20_b = gpd.sjoin(gdf20, gdf_buf4326, how='inner', predicate='intersects', lsuffix='left' ).reset_index()
gdf20_b.info()
gdf20_b.head()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        47 non-null     int64
#  1   latitude     47 non-null     float32
#  2   longitude    47 non-null     float32
#  3   to           47 non-null     float32
#  4   geometry     47 non-null     geometry
#  5   lat_lon      47 non-null     object
#  6   index_right  47 non-null     int64
# dtypes: float32(3), geometry(1), int64(2), object(1)
# memory usage: 2.1+ KB
#    index  latitude  longitude         to  \
# 0    713    36.375    131.375  22.417000
# 1    714    36.375    131.625  22.459000
# 2    715    36.375    131.875  22.700668
# 3    716    36.375    132.125  22.816000
# 4    751    36.625    130.875  22.438334
#
#                                             geometry         lat_lon  \
# 0  POLYGON ((131.37500 36.37500, 131.62500 36.375...  36.375_131.375
# 1  POLYGON ((131.62500 36.37500, 131.87500 36.375...  36.375_131.625
# 2  POLYGON ((131.87500 36.37500, 132.12500 36.375...  36.375_131.875
# 3  POLYGON ((132.12500 36.37500, 132.37500 36.375...  36.375_132.125
# 4  POLYGON ((130.87500 36.62500, 131.12500 36.625...  36.625_130.875
#
#    index_right
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
gdf20_b.explore('to')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba241ef9ef07635fb428adf377e637cc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba241ef9ef07635fb428adf377e637cc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba241ef9ef07635fb428adf377e637cc = L.map(
#                 &quot;map_ba241ef9ef07635fb428adf377e637cc&quot;,
#                 {
#                     center: [37.25, 131.875],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_ba241ef9ef07635fb428adf377e637cc);
#
#
#
#
#
#             var tile_layer_293637ef93492ed4b5b084e3706dea24 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ba241ef9ef07635fb428adf377e637cc);
#
#
#             map_ba241ef9ef07635fb428adf377e637cc.fitBounds(
#                 [[36.375, 130.875], [38.125, 132.875]],
#                 {}
#             );
#
#
#         function geo_json_7af2d0525871cb4ab144116de5259163_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#277e8e&quot;, &quot;fillColor&quot;: &quot;#277e8e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#24868e&quot;, &quot;fillColor&quot;: &quot;#24868e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;35&quot;:
#                     return {&quot;color&quot;: &quot;#32b67a&quot;, &quot;fillColor&quot;: &quot;#32b67a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#5ec962&quot;, &quot;fillColor&quot;: &quot;#5ec962&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;42&quot;:
#                     return {&quot;color&quot;: &quot;#26828e&quot;, &quot;fillColor&quot;: &quot;#26828e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;#355e8d&quot;, &quot;fillColor&quot;: &quot;#355e8d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#277f8e&quot;, &quot;fillColor&quot;: &quot;#277f8e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;#25838e&quot;, &quot;fillColor&quot;: &quot;#25838e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;9&quot;:
#                     return {&quot;color&quot;: &quot;#24aa83&quot;, &quot;fillColor&quot;: &quot;#24aa83&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;#a2da37&quot;, &quot;fillColor&quot;: &quot;#a2da37&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;#fde725&quot;, &quot;fillColor&quot;: &quot;#fde725&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;#2d708e&quot;, &quot;fillColor&quot;: &quot;#2d708e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;#365c8d&quot;, &quot;fillColor&quot;: &quot;#365c8d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;14&quot;:
#                     return {&quot;color&quot;: &quot;#33638d&quot;, &quot;fillColor&quot;: &quot;#33638d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;#23898e&quot;, &quot;fillColor&quot;: &quot;#23898e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2}

# %%
# # 연도 구분 컬럼 생성
# gdf21['year'] = 2021
# 위도-경도를 이용한 고유ID 부여
gdf21['lat_lon'] = gdf21['latitude'].astype(str) + '_' + gdf21['longitude'].astype(str)
# 독도 반경 영역에 해당하는 데이터만 추출 
gdf21_b = gpd.sjoin(gdf21, gdf_buf4326, how='inner', predicate='intersects', lsuffix='left' ).reset_index()

# %%
gdf21_b.explore('to')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0ff47ee32c276fe07f19435f94a9b8c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0ff47ee32c276fe07f19435f94a9b8c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0ff47ee32c276fe07f19435f94a9b8c3 = L.map(
#                 &quot;map_0ff47ee32c276fe07f19435f94a9b8c3&quot;,
#                 {
#                     center: [37.25, 131.875],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0ff47ee32c276fe07f19435f94a9b8c3);
#
#
#
#
#
#             var tile_layer_b6c3e5f3ddef60a4c7b66ce2883b000a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0ff47ee32c276fe07f19435f94a9b8c3);
#
#
#             map_0ff47ee32c276fe07f19435f94a9b8c3.fitBounds(
#                 [[36.375, 130.875], [38.125, 132.875]],
#                 {}
#             );
#
#
#         function geo_json_07910dd5831d6a41e9aea59f180ba7c9_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#26818e&quot;, &quot;fillColor&quot;: &quot;#26818e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#20928c&quot;, &quot;fillColor&quot;: &quot;#20928c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#1f9f88&quot;, &quot;fillColor&quot;: &quot;#1f9f88&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#58c765&quot;, &quot;fillColor&quot;: &quot;#58c765&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#3dbc74&quot;, &quot;fillColor&quot;: &quot;#3dbc74&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;#25858e&quot;, &quot;fillColor&quot;: &quot;#25858e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;#238a8d&quot;, &quot;fillColor&quot;: &quot;#238a8d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;#3d4e8a&quot;, &quot;fillColor&quot;: &quot;#3d4e8a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;9&quot;:
#                     return {&quot;color&quot;: &quot;#3b518b&quot;, &quot;fillColor&quot;: &quot;#3b518b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;#31678e&quot;, &quot;fillColor&quot;: &quot;#31678e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;#34b679&quot;, &quot;fillColor&quot;: &quot;#34b679&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;#2fb47c&quot;, &quot;fillColor&quot;: &quot;#2fb47c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;#21a585&quot;, &quot;fillColor&quot;: &quot;#21a585&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;14&quot;:
#                     return {&quot;color&quot;: &quot;#23a983&quot;, &quot;fillColor&quot;: &quot;#23a983&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;#25848e&quot;, &quot;fillColor&quot;: &quot;#25848e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;16&quot;:

# %% [markdown]
# 증감율 = [(기준시점 이후의 측정값 - 기준시점 이전의 측정값) ÷ 기준시점 이전의 측정값] × 100
# 증가율이 100%면 2배 증가한 것

# %%
# lat_lon 값을 기준으로 데이터 병합
merged_df = gdf20_b.merge(gdf21_b, on='lat_lon', suffixes=('_2020', '_2021'))

# %%
merged_df.head()
# Out:
#    index_2020  latitude_2020  longitude_2020    to_2020  \
# 0         713         36.375         131.375  22.417000
# 1         714         36.375         131.625  22.459000
# 2         715         36.375         131.875  22.700668
# 3         716         36.375         132.125  22.816000
# 4         751         36.625         130.875  22.438334
#
#                                        geometry_2020         lat_lon  \
# 0  POLYGON ((131.37500 36.37500, 131.62500 36.375...  36.375_131.375
# 1  POLYGON ((131.62500 36.37500, 131.87500 36.375...  36.375_131.625
# 2  POLYGON ((131.87500 36.37500, 132.12500 36.375...  36.375_131.875
# 3  POLYGON ((132.12500 36.37500, 132.37500 36.375...  36.375_132.125
# 4  POLYGON ((130.87500 36.62500, 131.12500 36.625...  36.625_130.875
#
#    index_right_2020  index_2021  latitude_2021  longitude_2021    to_2021  \
# 0                 0         713         36.375         131.375  23.767668
# 1                 0         714         36.375         131.625  23.817667
# 2                 0         715         36.375         131.875  23.858000
# 3                 0         716         36.375         132.125  23.991333
# 4                 0         751         36.625         130.875  23.951666
#
#                                        geometry_2021  index_right_2021
# 0  POLYGON ((131.37500 36.37500, 131.62500 36.375...                 0
# 1  POLYGON ((131.62500 36.37500, 131.87500 36.375...                 0
# 2  POLYGON ((131.87500 36.37500, 132.12500 36.375...                 0
# 3  POLYGON ((132.12500 36.37500, 132.37500 36.375...                 0
# 4  POLYGON ((130.87500 36.62500, 131.12500 36.625...                 0

# %%
# 증감률 계산: [(2021년 값 - 2020년 값) / 2020년 값] * 100
merged_df['growth_rate'] = ((merged_df['to_2021'] - merged_df['to_2020']) / merged_df['to_2020']) * 100

print(merged_df[['lat_lon', 'growth_rate']])
# Out:
#            lat_lon  growth_rate
# 0   36.375_131.375     6.025195
# 1   36.375_131.625     6.049545
# 2   36.375_131.875     5.098226
# 3   36.375_132.125     5.151354
# 4   36.625_130.875     6.744406
# 5   36.625_131.125     6.840475
# 6   36.625_131.375     6.971265
# 7   36.625_131.625     5.965507
# 8   36.625_131.875     5.217985
# 9   36.625_132.125     4.368376
# 10  36.625_132.375     3.233400
# 11  36.625_132.625     3.556391
# 12  36.875_130.875     7.070722
# 13  36.875_131.125     7.321136
# 14  36.875_131.375     7.203534
# 15  36.875_131.625     5.809846
# 16  36.875_131.875     6.064041
# 17  36.875_132.125     5.240392
# 18  36.875_132.375     4.639335
# 19  36.875_132.625     4.248854
# 20  37.125_130.875     9.561443
# 21  37.125_131.125     9.419824
# 22  37.125_131.375     8.360932
# 23  37.125_131.625     7.745859
# 24  37.125_131.875     7.043304
# 25  37.125_132.125     5.901570
# 26  37.125_132.375     4.901421
# 27  37.125_132.625     5.025776
# 28  37.375_130.875     9.079633
# 29  37.375_131.125     9.227164
# 30  37.375_131.375     7.822499
# 31  37.375_131.625     7.008480
# 32  37.375_131.875     7.079494
# 33  37.375_132.125     6.462331
# 34  37.375_132.375     5.778373
# 35  37.375_132.625     4.666121
# 36  37.625_130.875     9.481436
# 37  37.625_131.125     8.326396
# 38  37.625_131.375     7.776660
# 39  37.625_131.625     7.288064
# 40  37.625_131.875     7.066962
# 41  37.625_132.125     6.849524
# 42  37.625_132.375     6.983055
# 43  37.875_131.375     7.494246
# 44  37.875_131.625     6.955592
# 45  37.875_131.875     7.296408
# 46  37.875_132.125     7.163212

# %%
# 증감률이 높은 순서대로 정렬
merged_df2 = merged_df.sort_values(by='growth_rate', ascending=False)
merged_df2.head()
# Out:
#     index_2020  latitude_2020  longitude_2020    to_2020  \
# 20         831         37.125         130.875  22.064333
# 36         911         37.625         130.875  21.951666
# 21         832         37.125         131.125  22.102333
# 29         872         37.375         131.125  22.018333
# 28         871         37.375         130.875  22.064001
#
#                                         geometry_2020         lat_lon  \
# 20  POLYGON ((130.87500 37.12500, 131.12500 37.125...  37.125_130.875
# 36  POLYGON ((130.87500 37.62500, 131.12500 37.625...  37.625_130.875
# 21  POLYGON ((131.12500 37.12500, 131.37500 37.125...  37.125_131.125
# 29  POLYGON ((131.12500 37.37500, 131.37500 37.375...  37.375_131.125
# 28  POLYGON ((130.87500 37.37500, 131.12500 37.375...  37.375_130.875
#
#     index_right_2020  index_2021  latitude_2021  longitude_2021    to_2021  \
# 20                 0         831         37.125         130.875  24.174002
# 36                 0         911         37.625         130.875  24.032999
# 21                 0         832         37.125         131.125  24.184334
# 29                 0         872         37.375         131.125  24.050001
# 28                 0         871         37.375         130.875  24.067331
#
#                                         geometry_2021  index_right_2021  \
# 20  POLYGON ((130.87500 37.12500, 131.12500 37.125...                 0
# 36  POLYGON ((130.87500 37.62500, 131.12500 37.625...                 0
# 21  POLYGON ((131.12500 37.12500, 131.37500 37.125...                 0
# 29  POLYGON ((131.12500 37.37500, 131.37500 37.375...                 0
# 28  POLYGON ((130.87500 37.37500, 131.12500 37.375...                 0
#
#     growth_rate
# 20     9.561443
# 36     9.481436
# 21     9.419824
# 29     9.227164
# 28     9.079633

# %%
# Plotly 막대 차트를 그립니다.
fig = px.bar(merged_df2, x='lat_lon', y='growth_rate', title='2020년 대비 2021년 여름(6~8월) 수온 증감률')

# x축과 y축의 제목을 설정합니다.
fig.update_layout(
    xaxis_title="격자(위도_경도)",
    yaxis_title="증감률",
)

fig.show()

# %% [markdown]
# ### 지도 시각화

# %%
# 증감률 데이터에서 필요한 항목만 추출
merged_df3 = merged_df2[['lat_lon', 'growth_rate']]

# %%
# 2021년 공간(격자)데이터와 증감률 데이터를 속성조인
gdf21_c = pd.merge(gdf21_b, merged_df3, on='lat_lon', how='inner')

# %%
# 증감률을 지도시각화 
gdf21_c.explore('growth_rate', cmap='Reds', tiles='http://xdworld.vworld.kr:8080/2d/Satellite/service/{z}/{x}/{y}.jpeg', attr='브이월드')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9fff8312dc689cd491cc693d5e47f08 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9fff8312dc689cd491cc693d5e47f08&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9fff8312dc689cd491cc693d5e47f08 = L.map(
#                 &quot;map_a9fff8312dc689cd491cc693d5e47f08&quot;,
#                 {
#                     center: [37.25, 131.875],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_a9fff8312dc689cd491cc693d5e47f08);
#
#
#
#
#
#             var tile_layer_82f83663124c435a251f6b9755e42da2 = L.tileLayer(
#                 &quot;http://xdworld.vworld.kr:8080/2d/Satellite/service/{z}/{x}/{y}.jpeg&quot;,
#                 {&quot;attribution&quot;: &quot;\ube0c\uc774\uc6d4\ub4dc&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a9fff8312dc689cd491cc693d5e47f08);
#
#
#             map_a9fff8312dc689cd491cc693d5e47f08.fitBounds(
#                 [[36.375, 130.875], [38.125, 132.875]],
#                 {}
#             );
#
#
#         function geo_json_9d0f0d77abd8269f36a9488cb25fe2f6_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#fb7d5d&quot;, &quot;fillColor&quot;: &quot;#fb7d5d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#fb7c5c&quot;, &quot;fillColor&quot;: &quot;#fb7c5c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#fcad90&quot;, &quot;fillColor&quot;: &quot;#fcad90&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#fcaa8d&quot;, &quot;fillColor&quot;: &quot;#fcaa8d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;#f6553c&quot;, &quot;fillColor&quot;: &quot;#f6553c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;#f4503a&quot;, &quot;fillColor&quot;: &quot;#f4503a&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;: case &quot;42&quot;:
#                     return {&quot;color&quot;: &quot;#f24734&quot;, &quot;fillColor&quot;: &quot;#f24734&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#fc8060&quot;, &quot;fillColor&quot;: &quot;#fc8060&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;#fca689&quot;, &quot;fillColor&quot;: &quot;#fca689&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;9&quot;:
#                     return {&quot;color&quot;: &quot;#fdd1be&quot;, &quot;fillColor&quot;: &quot;#fdd1be&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;#fff5f0&quot;, &quot;fillColor&quot;: &quot;#fff5f0&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;#ffece4&quot;, &quot;fillColor&quot;: &quot;#ffece4&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;#e93529&quot;, &quot;fillColor&quot;: &quot;#e93529&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;14&quot;:
#                     return {&quot;color&quot;: &quot;#ee3a2c&quot;, &quot;fillColor&quot;: &quot;#ee3a2c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;#fc8767&quot;, &quot;fillColor&quot;: &quot;#fc8767&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;16&quot;:
#                     return {&quot;color&quot;: &quot;#fb7b5b&quot;, &quot;fillColor&quot;: &quot;#fb7b5b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;17&quo
